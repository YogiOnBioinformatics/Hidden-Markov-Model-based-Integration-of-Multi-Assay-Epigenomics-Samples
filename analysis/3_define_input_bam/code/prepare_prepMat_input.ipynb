# %% [markdown]
# # Define Input BAMs for IDEAS prepMat Tool

# %% [markdown]
# ## Purpose:

# %% [markdown]
# * Create 3-Column BAM Input File for `IDEAS prepMat` Tool

# %% [markdown]
# ## Packages and Options

# %%
import pandas as pd

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Read in Data

# %%
sample_sheet = pd.read_csv(
"/home/yraghav/CHDI-NeuroLINCS-Multi-Epigenomics-Annotation/ES_stage/inputs/sample_sheets/all_ATAC_and_ChIP.csv"
)

sample_sheet.head()
sample_sheet.tail()
# Out:
#              SampleID Condition      Treatment  Replicate  \
# 0     KO_H3K27Ac_rep1        KO     KO_H3K27Ac          1
# 1     KO_H3K27Ac_rep2        KO     KO_H3K27Ac          2
# 2     KO_H3K27Ac_rep3        KO     KO_H3K27Ac          3
# 3   KO_H3K27Ac_rep3-1        KO     KO_H3K27Ac          4
# 4  20-20_H3K27Ac_rep1      CTRL  20-20_H3K27Ac          1
#
#                                                                                                                                          bamReads  \
# 0     /nfs/latdata/yraghav/CHDI/chip/high_coverage_chip/2_BAMS/KO_H3K27Ac_rep1_210115Fra_D20-5575-3_NA_sequence.fastq.merged.nodup.no_chrM_MT.bam
# 1     /nfs/latdata/yraghav/CHDI/chip/high_coverage_chip/2_BAMS/KO_H3K27Ac_rep2_210115Fra_D20-5203-3_NA_sequence.fastq.merged.nodup.no_chrM_MT.bam
# 2     /nfs/latdata/yraghav/CHDI/chip/high_coverage_chip/2_BAMS/KO_H3K27Ac_rep3_210115Fra_D20-3512-2_NA_sequence.fastq.merged.nodup.no_chrM_MT.bam
# ...

# %%
sample_sheet = sample_sheet.sort_values(by=["Treatment"])

sample_sheet
# Out:
#                      SampleID   Condition          Treatment  Replicate  \
# 95            20-20_ATAC_rep1  CTRL_20-20         20-20_ATAC          1
# 96            20-20_ATAC_rep2  CTRL_20-20         20-20_ATAC          2
# 97            20-20_ATAC_rep3  CTRL_20-20         20-20_ATAC          3
# 4          20-20_H3K27Ac_rep1        CTRL      20-20_H3K27Ac          1
# 5          20-20_H3K27Ac_rep2        CTRL      20-20_H3K27Ac          2
# 6          20-20_H3K27Ac_rep3        CTRL      20-20_H3K27Ac          3
# 7        20-20_H3K27Ac_rep2-1        CTRL      20-20_H3K27Ac          4
# 8        20-20_H3K27Ac_rep3-1        CTRL      20-20_H3K27Ac          5
# 48      20-20_H3K27me3_rep3-1        CTRL     20-20_H3K27me3          3
# 46        20-20_H3K27me3_rep1        CTRL     20-20_H3K27me3          1
# 47        20-20_H3K27me3_rep2        CTRL     20-20_H3K27me3          2
# 51         20-20_H3K4me1_rep3        CTRL      20-20_H3K4me1          3
# ...

# %% [markdown]
# ## Create 3-Column Input for IDEAS prepMat

# %%
input_bams = pd.DataFrame()

input_bams["Cell Line"] = sample_sheet["Treatment"].str.split("_").str[0]

input_bams["Mark"] = sample_sheet["Treatment"].str.split("_").str[1] + "_" + sample_sheet["SampleID"].str.split("_").str[2]

input_bams["BAM"] = sample_sheet["bamReads"]

# %%
input_bams
# Out:
#     Cell Line             Mark  \
# 95      20-20        ATAC_rep1
# 96      20-20        ATAC_rep2
# 97      20-20        ATAC_rep3
# 4       20-20     H3K27Ac_rep1
# 5       20-20     H3K27Ac_rep2
# 6       20-20     H3K27Ac_rep3
# 7       20-20   H3K27Ac_rep2-1
# 8       20-20   H3K27Ac_rep3-1
# 48      20-20  H3K27me3_rep3-1
# 46      20-20    H3K27me3_rep1
# 47      20-20    H3K27me3_rep2
# 51      20-20     H3K4me1_rep3
# 50      20-20     H3K4me1_rep2
# 49      20-20     H3K4me1_rep1
# 74      20-20     H3K4me3_rep3
# 73      20-20     H3K4me3_rep2
# 72      20-20     H3K4me3_rep1
# 93      22-20        ATAC_rep2
# 92      22-20        ATAC_rep1
# 94      22-20        ATAC_rep3
# 11      22-20     H3K27Ac_rep3
# 10      22-20     H3K27Ac_rep2
# 9       22-20     H3K27Ac_rep1
# 44      22-20    H3K27me3_rep3
# 45      22-20  H3K27me3_rep1-1
# 42      22-20    H3K27me3_rep1
# 43      22-20    H3K27me3_rep2
# 54      22-20     H3K4me1_rep3
# 55      22-20   H3K4me1_rep3-1
# ...

# %% [markdown]
# ## Output to File

# %%
input_bams.to_csv(
"/home/yraghav/CHDI-NeuroLINCS-Multi-Epigenomics-Annotation/analysis/3_define_input_bam/output/bams.input", 
sep=" ", 
header=False, 
index=False
)
